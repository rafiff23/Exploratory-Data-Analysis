# %% [markdown]
# # Quiz: Exploratory Data Analysis
#
# Congratulations on completing the Exploratory Data Analysis course! We will conduct an assessment quiz to test your analytical thinking to explore data that you have learned on the course. The quiz is expected to be taken in the classroom, please contact our teaching team if you missed the chance to take it in class.

# %% [markdown]
# # Bukalapak Dataset

# %% [markdown]
# ## Data Preparation
#
#
# We will use **e-commerce product dataset**. You can use the data in the csv file extension stored in the `online_bl.csv` file in `data_input` folder.
#
# The data contain information on products sold on the e-commerce website Bukalapak.com. The data has several variables, including:
#
# - `item_link` : product website link in the list
# - `title` : the name of the product being sold
# - `price_original` : product price
# - `price_discount` : product discount price
# - `sub_category` : sub-category product
# - `time_update` : time to upload product information on the website
# - `scale` : product unit scale
#
# Please import `online_bl.csv` dataset from `data_input` folder and assign it into `online_bl` variable. As our dataset has datetime information, please use `parse_dates=[]` in `read_csv()` method to convert `time_update` column into datetime data type and store it into `online_bl`.

# %%
import pandas as pd

# %%
## Import Library & Read Data

online_bl = pd.read_csv('data_input/online_bl.csv', parse_dates=['time_update'])
online_bl.head()
# Out:
#                                            item_link  \
# 0  https://www.bukalapak.com/p/kesehatan-2359/pro...
# 1  https://www.bukalapak.com/p/rumah-tangga/home-...
# 2  https://www.bukalapak.com/p/rumah-tangga/home-...
# 3  https://www.bukalapak.com/p/rumah-tangga/home-...
# 4  https://www.bukalapak.com/p/rumah-tangga/home-...
#
#                                                title  price_original  \
# 0                  Rinso Molto Deterjen Bubuk 1.8 kg         30000.0
# 1  Terlaris - DETERGENT RINSO ANTI NODA 1.8 KG 1 ...         49000.0
# 2                     Good Rinso Molto Purple 1.8 Kg         50000.0
# 3                    Order Rinso Molto Purple 1.8 Kg         49000.0
# 4                 Promonya Rinso Molto Purple 1.8 Kg         49000.0
#
#    price_discount sub_category         time_update   scale
# 0             NaN    detergent 2018-10-20 01:32:00  1.8 kg
# 1             NaN    detergent 2018-09-20 01:02:00  1.8 kg
# 2             NaN    detergent 2018-10-13 10:46:00  1.8 kg
# 3             NaN    detergent 2018-09-24 15:17:00  1.8 kg
# 4             NaN    detergent 2018-09-27 11:16:00  1.8 kg

# %% [markdown]
# Based on `online_bl` dataset you will perform data exploration to ensure it is ready for analysis. The first thing you will do is data type checking.

# %%
# your code here
online_bl.dtypes
# Out:
# item_link                 object
# title                     object
# price_original           float64
# price_discount           float64
# sub_category            category
# time_update       datetime64[ns]
# scale                     object
# dtype: object

# %% [markdown]
# As we know, `sub_category` column doesn't have appropriate data type. Please change it into the appropriate data type.

# %%
# your code here
online_bl['sub_category'] = online_bl['sub_category'].astype('category')

# %% [markdown]
# ## Analysis
#
# In the `online_bl` dataset stores several categories sold in e-commerce. You are asked to analyze the data and answer a number of questions.

# %% [markdown]
# ### Product Categories
#
# You want to find out what sub categories (`sub_category`) are being sold. You will find out what categories is mostly sold in those e-commerce. Using the information from the `sub_category` column, please answer the questions below.
#
# 1. How many unique sub categories(`sub_category`) are there in `online_bl` dataset? Do we have more "detergent" listings or "sugar" listings within our data?
#
#     *Berapa banyak jenis barang (`sub_category`) unik yang ada dalam kumpulan data `online_bl`? Apakah kita memiliki lebih banyak daftar "Detergent" atau "Sugar" pada data tersebut?*
#
#     - [ ] 2, with more "detergent" than "sugar"
#     - [ ] 2, with "detergent" and "sugar" having equal listings
#     - [x] 3, with more "sugar" than detergent
#     - [ ] None of above is correct

# %%
online_bl['sub_category'].cat.categories
# Out:
# Index(['detergent', 'rice', 'sugar'], dtype='object')

# %%
online_bl[online_bl['sub_category'] == 'detergent']
# Out:
#                                              item_link  \
# 0    https://www.bukalapak.com/p/kesehatan-2359/pro...
# 1    https://www.bukalapak.com/p/rumah-tangga/home-...
# 2    https://www.bukalapak.com/p/rumah-tangga/home-...
# 3    https://www.bukalapak.com/p/rumah-tangga/home-...
# 4    https://www.bukalapak.com/p/rumah-tangga/home-...
# ..                                                 ...
# 101  https://www.bukalapak.com/p/rumah-tangga/perle...
# 102  https://www.bukalapak.com/p/rumah-tangga/perle...
# 103  https://www.bukalapak.com/p/rumah-tangga/perle...
# 104  https://www.bukalapak.com/p/rumah-tangga/perle...
# 105  https://www.bukalapak.com/p/rumah-tangga/perle...
#
#                                                  title  price_original  \
# 0                    Rinso Molto Deterjen Bubuk 1.8 kg         30000.0
# 1    Terlaris - DETERGENT RINSO ANTI NODA 1.8 KG 1 ...         49000.0
# 2                       Good Rinso Molto Purple 1.8 Kg         50000.0
# 3                      Order Rinso Molto Purple 1.8 Kg         49000.0
# 4                   Promonya Rinso Molto Purple 1.8 Kg         49000.0
# ..                                                 ...             ...
# 101                             Rinso Anti Noda 1.8 kg         27900.0
# 102                             RINSO ANTI NODA 1.8 kg         30500.0
# 103                             Rinso Anti Noda 1.8 kg         28500.0
# 104                             Rinso anti noda 1.8 kg         27000.0
# 105              Rinso Anti Noda Antinoda Molto 1.8 kg         27900.0
#
#      price_discount sub_category         time_update   scale
# 0               NaN    detergent 2018-10-20 01:32:00  1.8 kg
# 1               NaN    detergent 2018-09-20 01:02:00  1.8 kg
# 2               NaN    detergent 2018-10-13 10:46:00  1.8 kg
# 3               NaN    detergent 2018-09-24 15:17:00  1.8 kg
# 4               NaN    detergent 2018-09-27 11:16:00  1.8 kg
# ..              ...          ...                 ...     ...
# 101             NaN    detergent 2018-10-10 01:37:00  1.8 kg
# 102             NaN    detergent 2018-10-05 11:53:00  1.8 kg
# 103             NaN    detergent 2018-10-20 09:31:00  1.8 kg
# 104             NaN    detergent 2018-10-17 03:00:00  1.8 kg
# 105             NaN    detergent 2018-10-22 10:56:00  1.8 kg
#
# [106 rows x 7 columns]

# %% [markdown]
# ### Product Scales
#
# Based on the several sub categories sold above, each item is sold in several size based on its weight, including detergent. Detergents on the market have several scale options (1kg, 1.8kg, etc.).
#
# 2. In which scale do we have our **detergent** stock the most?
#
#     *Deterjen dengan ukuran berapakah yang paling banyak dijual di situs Bukalapak?*
#
#     - [ ] 1 kg
#     - [x] 1.8 kg
#     - [ ] 5 kg
#     - [ ] 800 gr

# %%
online_bl.dtypes
# Out:
# item_link                 object
# title                     object
# price_original           float64
# price_discount           float64
# sub_category            category
# time_update       datetime64[ns]
# scale                     object
# dtype: object

# %%
online_bl['scale'].value_counts()
# Out:
# 1 kg      364
# 5 kg      274
# 1.8 kg     88
# 800 gr     18
# Name: scale, dtype: int64

# %%
# cara 1
pd.pivot_table(
    data=online_bl,
    index='scale',
    columns='sub_category',
    values='item_link',
    aggfunc='count'
)
# Out:
# sub_category  detergent   rice  sugar
# scale
# 1 kg                NaN  212.0  152.0
# 1.8 kg             88.0    NaN    NaN
# 5 kg                NaN  213.0   61.0
# 800 gr             18.0    NaN    NaN

# %% [markdown]
# Suddenly, you are in need of detergent. Based on the detergent scale information and the market price, you are interested in buying a detergent with scales of 1.8 kg and 800 grams. However, at this time you want to know what month is the detergent on that scales is sold at the lowest average price.
#
# 3. Which month has the **lowest average price** (`mean` on `price_original`) for detergent products (1.8kg and 800gr respectively) listed for sale on Bukalapak? Are they the same month?
#
#     *Di bulan apakah produk deterjen dengan ukuran 1,8 kg dan 800 gram berada di rata-rata harga terendah? Apakah keduanya berada di bulan yang sama?*
#
#     - [ ] Both 1.8 kg and 800 gr detergents lowest price were in August
#     - [ ] Both 1.8 kg and 800 gr detergents lowest price were in October
#     - [x] 1.8 kg detergents: Lowest in August, 800 gr: Lowest in October
#     - [ ] 1.8 kg detergents: Lowest in August, 800 gr: Lowest in July

# %%
online_bl['time_update2'] = online_bl['time_update'].dt.month_name()

# %%
online_bl['time_update2']
# Out:
# 0        October
# 1      September
# 2        October
# 3      September
# 4      September
#          ...
# 739      October
# 740      October
# 741      October
# 742      October
# 743      October
# Name: time_update2, Length: 744, dtype: object

# %%
pd.pivot_table(
    data=online_bl,
    index=['time_update2','scale'],
    columns='sub_category',
    values='price_original',
    aggfunc='mean'
)
# Out:
# sub_category            detergent           rice          sugar
# time_update2 scale
# August       1 kg             NaN   73465.000000   40700.000000
#              1.8 kg  31000.000000            NaN            NaN
#              5 kg             NaN  126052.941176   90000.000000
#              800 gr  20000.000000            NaN            NaN
# January      1 kg             NaN            NaN   18500.000000
# July         1 kg             NaN   76800.000000   21028.571429
#              1.8 kg  40000.000000            NaN            NaN
#              5 kg             NaN   73250.000000  221000.000000
#              800 gr  30000.000000            NaN            NaN
# June         1 kg             NaN  110333.333333   51900.000000
#              5 kg             NaN   85000.000000   90000.000000
# March        1 kg             NaN            NaN  210100.000000
#              5 kg             NaN  142500.000000   11900.000000
# May          1 kg             NaN  113333.333333   15000.000000
#              5 kg             NaN   85000.000000            NaN
# October      1 kg             NaN   45177.372263   50284.946237
#              1.8 kg  41191.836735            NaN            NaN
#              5 kg             NaN   86884.285714  131444.444444
#              800 gr  21945.454545            NaN            NaN
# September    1 kg             NaN   58489.743590   55071.794872
#              1.8 kg  42750.000000            NaN            NaN
#              5 kg             NaN   75406.976744  126425.925926
#              800 gr  33475.000000            NaN            NaN

# %%
techcrunch[techcrunch['company'] == 'Friendster']

# %%
pd.pivot_table(
    data=online_bl,
    index=['company'] == 'Friendster,
    columns='sub_category',
    values='price_original',
    aggfunc='mean'
)
# Out:
#   Input In [75]
#     index=['company'] == 'Friendster,
#                                      ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# ---

# %% [markdown]
# # Fund Raising Dataset

# %% [markdown]
# ## Data Preparation
#
# In the second analysis, you will use the **fund raising** dataset obtained by several startup companies in America. Please use `techcrunch.csv` data from `data_input` folder. The dataset contains the following variables:
#
# - `permalink` : name of permalink company
# - `company` : company name (company)
# - `numEmps` : number of media partners
# - `category` : company category
# - `city` : the name of the city where the company is located
# - `state` : state code of company location
# - `fundedDate` : funding date
# - `raisedAmt` : the amount of funding obtained
# - `raisedCurrency` : information

# %%
## Your code here

techcrunch = pd.read_csv('data_input/techcrunch.csv')
techcrunch
# Out:
#           permalink        company  numEmps  category        city state  \
# 0          lifelock       LifeLock      NaN       web       Tempe    AZ
# 1          lifelock       LifeLock      NaN       web       Tempe    AZ
# 2          lifelock       LifeLock      NaN       web       Tempe    AZ
# 3       mycityfaces    MyCityFaces      7.0       web  Scottsdale    AZ
# 4          flypaper       Flypaper      NaN       web     Phoenix    AZ
# ...             ...            ...      ...       ...         ...   ...
# 1455        trusera        Trusera     15.0       web     Seattle    WA
# 1456     alerts-com     Alerts.com      NaN       web    Bellevue    WA
# 1457          myrio          Myrio     75.0  software     Bothell    WA
# 1458  grid-networks  Grid Networks      NaN       web     Seattle    WA
# 1459  grid-networks  Grid Networks      NaN       web     Seattle    WA
#
#      fundedDate  raisedAmt raisedCurrency         round
# 0      1-May-07    6850000            USD             b
# 1      1-Oct-06    6000000            USD             a
# 2      1-Jan-08   25000000            USD             c
# 3      1-Jan-08      50000            USD          seed
# 4      1-Feb-08    3000000            USD             a
# ...         ...        ...            ...           ...
# 1455   1-Jun-07    2000000            USD         angel
# 1456   8-Jul-08    1200000            USD             a
# 1457   1-Jan-01   20500000            USD  unattributed
# 1458  30-Oct-07    9500000            USD             a
# 1459  20-May-08   10500000            USD             b
#
# [1460 rows x 10 columns]

# %%
techcrunch.dtypes
# Out:
# permalink           object
# company             object
# numEmps            float64
# category          category
# city                object
# state               object
# fundedDate          object
# raisedAmt            int64
# raisedCurrency    category
# round             category
# dtype: object

# %%
techcrunch.nunique()
# Out:
# permalink         909
# company           909
# numEmps            72
# category            8
# city              193
# state              33
# fundedDate        386
# raisedAmt         281
# raisedCurrency      3
# round               9
# dtype: int64

# %% [markdown]
# Before exploring further data, please adjust some of the columns that don't have the appropriate data type in order to reduce memory.

# %%
## Your code here
cats = ['category','raisedCurrency','round']
techcrunch[cats] = techcrunch[cats].astype('category')

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Funding each Category
#
# As someone who wants to run a startup, you want to do a fairly thorough funding plan, so that your company runs well. Therefore, you are interested in finding out which startup `category` gets the highest funding. Since there are many startups working in the same field, you will want to get a summary of the average amount of funding (`raisedAmt`) given. As you already know, the average value will be affected by outliers, so you will use the median value to get a summary of the startup fields that get the highest funding.
#
# Based on the conditions, answer the questions below.
#
# 4. Which `category` raised the most amount in funding (`raisedAmt`) on average (use the `median`)?
#
#     *Kategori (`category`) startup manakah yang mendapatkan rata-rata (gunakan `median`) funding (`raisedAmt`) tertinggi?*
#
#     - [ ] `mobile`
#     - [ ] `cleantech`
#     - [x] `biotech`
#     - [ ] `consulting`

# %%
## Your code here
pd.pivot_table(
    data=techcrunch,
    index='category',
    values='raisedAmt',
    aggfunc='median'
)
# Out:
#             raisedAmt
# category
# biotech      20000000
# cleantech    15500000
# consulting    7000000
# hardware     13700000
# mobile        5000000
# other         7750000
# software      7125000
# web           5000000

# %% [markdown]
# ### Funding each Company
#
# As a social media user, you are interested in analyzing one of the social media that is included in the list of startups receiving funding, namely **Friendster**. During the funding period, Friendster always gain different amount of funding.
#
# 5. In which period does Friendster gain their highest raised amount of funding?
#
#    *Pada periode manakah Friendster mendapatkan nilai funding tertinggi mereka?*
#
#     - [x] 2008-08
#     - [ ] 2002-12
#     - [ ] 2006-08
#     - [ ] 2012-01

# %%
techcrunch[techcrunch['company'] == 'Friendster']
# Out:
#       permalink     company  numEmps category           city state fundedDate  \
# 318  friendster  Friendster    465.0      web  San Francisco    CA   1-Dec-02
# 319  friendster  Friendster    465.0      web  San Francisco    CA   1-Oct-03
# 320  friendster  Friendster    465.0      web  San Francisco    CA   1-Aug-06
# 321  friendster  Friendster    465.0      web  San Francisco    CA   5-Aug-08
#
#      raisedAmt raisedCurrency round
# 318    2400000            USD     a
# 319   13000000            USD     b
# 320   10000000            USD     c
# 321   20000000            USD     d

# %%
city2 = techcrunch[techcrunch['city'] == 'San Francisco']

# %%
pd.pivot_table(
    data=techcrunch,
    index='category',
    values='raisedAmt',
    aggfunc='median'
)
# Out:
#             raisedAmt
# category
# biotech      20000000
# cleantech    15500000
# consulting    7000000
# hardware     13700000
# mobile        5000000
# other         7750000
# software      7125000
# web           5000000

# %% [markdown]
# After looking at several startups that have received funding, you want to find out more about startups that have successfully received funding in your location, **San Francisco**. Create an aggregation of data showing some of the highest to lowest funded companies in San Francisco.
#
# 6.  Among all companies in San Francisco, which of the following are **not** among the top 5 most funded ( has highest **total** `raisedAmt`) companies?
#
#     *Perusahaan apa yang **TIDAK** termasuk 5 perusahaan dengan **total** funding (`raisedAmt`) tertinggi di San Francisco?*
#
#     - [x] `OpenTable`
#     - [ ] `Friendster`
#     - [ ] `Facebook`
#     - [x] `Snapfish`

# %%
city2.sort_values(by='raisedAmt', ascending=True).tail(20)
# Out:
#                permalink               company  numEmps  category  \
# 304                mevio                 Mevio      NaN       web
# 305                mevio                 Mevio      NaN       web
# 206               tagged                Tagged      NaN       web
# 523            playfirst             PlayFirst      NaN       web
# 345        deliveryagent        Delivery Agent      NaN       web
# 202                  hi5                   hi5    100.0       web
# 321           friendster            Friendster    465.0       web
# 65               prosper               Prosper      NaN       web
# 162           healthline            Healthline      NaN       web
# 615             coverity              Coverity      NaN  software
# 312        atomshockwave        Atom Shockwave      NaN       web
# 148              adbrite               AdBrite      NaN       web
# 289           bittorrent            BitTorrent     29.0       web
# 581                zynga                 Zynga     90.0     other
# 442           automattic            Automattic     20.0       web
# 259             snapfish              Snapfish      NaN       web
# 341            opentable             OpenTable      NaN       web
# 126  metawebtechnologies  Metaweb Technologies      NaN       web
# 125             freebase              freebase      NaN       web
# 122                slide                 Slide     64.0       web
#
#               city state fundedDate  raisedAmt raisedCurrency round
# 304  San Francisco    CA   1-Sep-06   15000000            USD     b
# 305  San Francisco    CA   9-Jul-08   15000000            USD     c
# 206  San Francisco    CA   1-Jul-07   15000000            USD     b
# 523  San Francisco    CA   1-Dec-07   16500000            USD     c
# 345  San Francisco    CA   1-May-07   18500000            USD     c
# 202  San Francisco    CA   1-Jul-07   20000000            USD     a
# 321  San Francisco    CA   5-Aug-08   20000000            USD     d
# 65   San Francisco    CA   1-Jun-07   20000000            USD     c
# 162  San Francisco    CA   1-Jul-07   21000000            USD     b
# 615  San Francisco    CA   1-Feb-08   22000000            USD     a
# 312  San Francisco    CA   1-Mar-01   22900000            USD     a
# 148  San Francisco    CA   1-Nov-07   23000000            USD     c
# 289  San Francisco    CA   1-Dec-06   25000000            USD     b
# 581  San Francisco    CA  22-Jul-08   29000000            USD     b
# 442  San Francisco    CA   1-Jan-08   29500000            USD     b
# 259  San Francisco    CA   1-May-00   36000000            USD     b
# 341  San Francisco    CA   1-Oct-00   36000000            USD     c
# 126  San Francisco    CA  15-Jan-08   42000000            USD     b
# 125  San Francisco    CA   1-Jan-08   42500000            USD     b
# 122  San Francisco    CA   1-Jan-08   50000000            USD     d

# %%
pd.pivot_table(
    data=techcrunch,
    index='city',
    columns='company',
    values='raisedAmt',
    aggfunc='sum'
).loc[['San Francisco']]
# Out:
# company        23andMe  3Jam  4HomeMedia  5min  750 Industries  A123Systems  \
# city
# San Francisco      NaN   NaN         NaN   NaN       1000000.0          NaN
#
# company        Accertify  AccountNow  Acinion  Acquia  ...  samfind  \
# city                                                   ...
# San Francisco        NaN         NaN      NaN     NaN  ...      NaN
#
# company           seesmic  trueAnthem  tubemogul  uTest  uber  utoopia  \
# city
# San Francisco  12000000.0         NaN        NaN    NaN   NaN      NaN
#
# company        vbs tv  x+1  xkoto
# city
# San Francisco     NaN  NaN    NaN
#
# [1 rows x 895 columns]

# %%
pd.crosstab(
    index=techcrunch['city'],
    columns=techcrunch['company'],
    values=techcrunch['raisedAmt'],
    aggfunc='sum')
# .loc[['San Francisco']]
# Out:
# company        23andMe  3Jam  4HomeMedia  5min  750 Industries  A123Systems  \
# city
# Acton              NaN   NaN         NaN   NaN             NaN          NaN
# Agoura Hills       NaN   NaN         NaN   NaN             NaN          NaN
# Alameda            NaN   NaN         NaN   NaN             NaN          NaN
# Albuquerque        NaN   NaN         NaN   NaN             NaN          NaN
# Aliso Viejo        NaN   NaN         NaN   NaN             NaN          NaN
# ...                ...   ...         ...   ...             ...          ...
# Westport           NaN   NaN         NaN   NaN             NaN          NaN
# Westwood           NaN   NaN         NaN   NaN             NaN          NaN
# Winston-Salem      NaN   NaN         NaN   NaN             NaN          NaN
# Woburn             NaN   NaN         NaN   NaN             NaN          NaN
# Woodside           NaN   NaN         NaN   NaN             NaN          NaN
#
# company        Accertify  AccountNow     Acinion  Acquia  ...  samfind  \
# city                                                      ...
# Acton                NaN         NaN  21000000.0     NaN  ...      NaN
# Agoura Hills         NaN         NaN         NaN     NaN  ...      NaN
# Alameda              NaN         NaN         NaN     NaN  ...      NaN
# Albuquerque          NaN         NaN         NaN     NaN  ...      NaN
# Aliso Viejo          NaN         NaN         NaN     NaN  ...      NaN
# ...                  ...         ...         ...     ...  ...      ...
# Westport             NaN         NaN         NaN     NaN  ...      NaN
# Westwood             NaN         NaN         NaN     NaN  ...      NaN
# Winston-Salem        NaN         NaN         NaN     NaN  ...      NaN
# Woburn               NaN         NaN         NaN     NaN  ...      NaN
# Woodside             NaN         NaN         NaN     NaN  ...      NaN
#
# company        seesmic  trueAnthem  tubemogul  uTest  uber  utoopia  vbs tv  \
# city
# Acton              NaN         NaN        NaN    NaN   NaN      NaN     NaN
# Agoura Hills       NaN         NaN        NaN    NaN   NaN      NaN     NaN
# Alameda            NaN         NaN        NaN    NaN   NaN      NaN     NaN
# Albuquerque        NaN         NaN        NaN    NaN   NaN      NaN     NaN
# Aliso Viejo        NaN         NaN        NaN    NaN   NaN      NaN     NaN
# ...                ...         ...        ...    ...   ...      ...     ...
# Westport           NaN         NaN        NaN    NaN   NaN      NaN     NaN
# Westwood           NaN         NaN        NaN    NaN   NaN      NaN     NaN
# Winston-Salem      NaN         NaN        NaN    NaN   NaN      NaN     NaN
# Woburn             NaN         NaN        NaN    NaN   NaN      NaN     NaN
# Woodside           NaN         NaN        NaN    NaN   NaN      NaN     NaN
#
# company        x+1  xkoto
# city
# Acton          NaN    NaN
# Agoura Hills   NaN    NaN
# Alameda        NaN    NaN
# Albuquerque    NaN    NaN
# Aliso Viejo    NaN    NaN
# ...            ...    ...
# Westport       NaN    NaN
# Westwood       NaN    NaN
# Winston-Salem  NaN    NaN
# Woburn         NaN    NaN
# Woodside       NaN    NaN
#
# [193 rows x 895 columns]

# %%
trx_ym_format
# Out:
# city            Acton  Agoura Hills  Alameda  Albuquerque  Aliso Viejo  \
# company
# 23andMe           NaN           NaN      NaN          NaN          NaN
# 3Jam              NaN           NaN      NaN          NaN          NaN
# 4HomeMedia        NaN           NaN      NaN          NaN          NaN
# 5min              NaN           NaN      NaN          NaN          NaN
# 750 Industries    NaN           NaN      NaN          NaN          NaN
# ...               ...           ...      ...          ...          ...
# uber              NaN           NaN      NaN          NaN          NaN
# utoopia           NaN           NaN      NaN          NaN          NaN
# vbs tv            NaN           NaN      NaN          NaN          NaN
# x+1               NaN           NaN      NaN          NaN          NaN
# xkoto             NaN           NaN      NaN          NaN          NaN
#
# city            Allentown  American Fork  Andover  Ann Arbor  Arlington  ...  \
# company                                                                  ...
# 23andMe               NaN            NaN      NaN        NaN        NaN  ...
# 3Jam                  NaN            NaN      NaN        NaN        NaN  ...
# 4HomeMedia            NaN            NaN      NaN        NaN        NaN  ...
# 5min                  NaN            NaN      NaN        NaN        NaN  ...
# 750 Industries        NaN            NaN      NaN        NaN        NaN  ...
# ...                   ...            ...      ...        ...        ...  ...
# uber                  NaN            NaN      NaN        NaN        NaN  ...
# utoopia               NaN            NaN      NaN        NaN        NaN  ...
# vbs tv                NaN            NaN      NaN        NaN        NaN  ...
# x+1                   NaN            NaN      NaN        NaN        NaN  ...
# xkoto                 NaN            NaN      NaN        NaN        NaN  ...
#
# city            Wellesley  West Hollywood  West Palm Beach  Westborough  \
# company
# 23andMe               NaN             NaN              NaN          NaN
# 3Jam                  NaN             NaN              NaN          NaN
# 4HomeMedia            NaN             NaN              NaN          NaN
# 5min                  NaN             NaN              NaN          NaN
# 750 Industries        NaN             NaN              NaN          NaN
# ...                   ...             ...              ...          ...
# uber                  NaN             NaN              NaN          NaN
# utoopia               NaN             NaN              NaN          NaN
# vbs tv                NaN             NaN              NaN          NaN
# x+1                   NaN             NaN              NaN          NaN
# xkoto                 NaN             NaN              NaN          NaN
#
# city            Westlake Village  Westport  Westwood  Winston-Salem  Woburn  \
# company
# 23andMe                      NaN       NaN       NaN            NaN     NaN
# 3Jam                         NaN       NaN       NaN            NaN     NaN
# 4HomeMedia                   NaN       NaN       NaN            NaN     NaN
# 5min                         NaN       NaN       NaN            NaN     NaN
# 750 Industries               NaN       NaN       NaN            NaN     NaN
# ...                          ...       ...       ...            ...     ...
# uber                         NaN       NaN       NaN            NaN     NaN
# utoopia                      NaN       NaN       NaN            NaN     NaN
# vbs tv                       NaN       NaN       NaN            NaN     NaN
# x+1                          NaN       NaN       NaN            NaN     NaN
# xkoto                        NaN       NaN       NaN            NaN     NaN
#
# city            Woodside
# company
# 23andMe              NaN
# 3Jam                 NaN
# 4HomeMedia           NaN
# 5min                 NaN
# 750 Industries       NaN
# ...                  ...
# uber                 NaN
# utoopia              NaN
# vbs tv               NaN
# x+1                  NaN
# xkoto                NaN
#
# [895 rows x 193 columns]
